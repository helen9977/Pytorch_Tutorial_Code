# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torch.autograd import Variable
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import os
from datetime import datetime
from PIL import Image
import matplotlib.pyplot as plt

# %%
pwd = '/content/drive/My Drive/python/PyTorch_Tutorial'
train_txt_path = os.path.join(pwd, '..','..','Data','train.txt')
train_dir = os.path.join(pwd, '..','..','Data', 'train')

valid_txt_path = os.path.join(pwd, '..','..','Data','Valid.txt')
valid_dir = os.path.join(pwd, '..','..','Data','valid')

classes_name = ['plane','car','bird','cat','deer','dog','frog','horse','ship','truck']

train_bs = 64
valid_bs = 64
lr_init = 0.001
max_epoch = 200

result_dir = os.path.join(pwd, '..','..','Data','Result')
now_time = datetime.now()
time_str = datetime.strftime(now_time, '%m-%d_%H-%M-%S')

log_dir = os.path.join(result_dir, time_str)
if not os.path.exists(log_dir):
  os.makedirs(log_dir)

# %%
class MyDataset(Dataset):
    def __init__(self, txt_path, transform = None, target_transform = None):
        fh = open(txt_path, 'r')
        imgs = []
        for line in fh:
            line = line.rstrip()
            words = line.split('*')
            imgs.append((words[0], int(words[1])))

        self.imgs = imgs        # 最主要就是要生成这个list， 然后DataLoader中给index，通过getitem读取图片数据
        self.transform = transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        fn, label = self.imgs[index]
        img = Image.open(fn).convert('RGB')     # 像素值 0~255，在transfrom.totensor会除以255，使像素值变成 0~1

        if self.transform is not None:
            img = self.transform(img)   # 在这里做transform，转为tensor等等

        return img, label

    def __len__(self):
        return len(self.imgs)

# %%
def validate(net, data_loader, set_name, classes_name):
  net.eval()
  cls_num = len(classes_name)
  conf_mat = np.zeros([cls_num, cls_num])

  for data in data_loader:
    images, labels = data
    images = Variable(images)
    labels = Variable(labels)

    outputs = net(images)
    outputs.detach_()

    _, predicted = torch.max(outputs.data, 1)

    # 统计混淆矩阵
    for i in range(len(labels)):
      cate_i = labels[i].numpy()
      pre_i = predicted[i].numpy()
      conf_mat[cate_i, pre_i] += 1.0


  for i in range(cls_num):
    print('class;{:<10}, total num:{:<6}, correct num:{:<5}  Recall:{:.2%}  Precision:{:.2%}'
    .format(classes_name[i], np.sum(conf_mat[i,:]), conf_mat[i, i], conf_mat[i, i]/(1+np.sum(conf_mat[i,:])),
           conf_mat[i,i] / (1 + np.sum(conf_mat[:, i]))))
    
  print('{} set Accuracy:{:.2%}'.format(set_name, np.trace(conf_mat) / np.sum(conf_mat))) # trace 对角线元素求和
  
  return conf_mat, '{:.2}'.format(np.trace(conf_mat) / np.sum(conf_mat))



def show_confMat(confusion_mat, classes, set_name, out_dir):

  #归一化
  confusion_mat_N = confusion_mat.copy()
  for i in range(len(classes)):
    confusion_mat_N[i, :] = confusion_mat[i, :] / confusion_mat[i, :].sum()

  #获取颜色
  cmap = plt.cm.get_cmap('Greys')
  plt.imshow(confusion_mat_N, cmap=cmap)
  plt.colorbar()

  #设置文字
  xlocations = np.array(range(len(classes)))
  plt.xticks(xlocations, list(classes), rotation=60)
  plt.yticks(xlocations, list(classes))
  plt.xlabel('Predict label')
  plt.ylabel('True label')
  plt.title('Confusion_Matrix_' + set_name)

  #打印数字
  for i in range(confusion_mat_N.shape[0]):
    for j in range(confusion_mat_N.shape[1]):
      plt.text(x=j, y=i, s=int(confusion_mat[i,j]), va='center', ha='center',
               color='red', fontsize=10)
      
  #保存
  plt.savefig(os.path.join(out_dir,'Confusion_Matrix' + set_name + '.png'))
  plt.close()

# %%
#------- step 1/5 加载数据

# 数据预处理设置

normMean = [0.4948052, 0.48568845, 0.44682974]
normStd = [0.24580306, 0.24236229, 0.2603115]
normTransform = transforms.Normalize(normMean, normStd)
trainTransform = transforms.Compose([
                                     transforms.Resize(32),
                                     transforms.RandomCrop(32, padding=4),
                                     transforms.ToTensor(),
                                     normTransform
])

validTransform = transforms.Compose([
                                     transforms.ToTensor(),
                                     normTransform
])

# 构建Mydataset实例
train_data = MyDataset(txt_path=train_txt_path, transform=trainTransform)
valid_data = MyDataset(txt_path=valid_txt_path, transform=validTransform)

#构建DataLoder
train_loader = DataLoader(dataset=train_data, batch_size=train_bs, shuffle=True)
valid_loader = DataLoader(dataset=valid_data, batch_size=valid_bs)

# %%
#--------- step 2/5: 定义网络

class Net(nn.Module):
  def __init__(self):
    super(Net,self).__init__()
    self.conv1 = nn.Conv2d(3, 6, 5)
    self.pool1 = nn.MaxPool2d(2, 2)
    self.conv2 = nn.Conv2d(6, 16, 5)
    self.pool2 = nn.MaxPool2d(2, 2)
    self.fc1 = nn.Linear(16 * 5 * 5, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)

  def forward(self, x):
    x = self.pool1(F.relu(self.conv1(x)))
    x = self.pool2(F.relu(self.conv2(x)))
    x = x.view(-1, 16 * 5 * 5)
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)
    return x

  #定义权值初始化
  def initialize_weights(self):
    for m in self.modules():
      if isinstance(m,nn.Conv2d):
        torch.nn.init.xavier_normal_(m.weight.data)
        if m.bias is not None:
          m.bias.data.zero_()
      elif isinstance(m,nn.BatchNorm2d):
        m.weight.data.fill_(1)
        m.bias.data.zero_()
      elif isinstance(m,nn.Linear):
        torch.nn.init.normal_(m.weight.data, 0, 0.01)
        m.bias.data.zero_()

net = Net()

# load params
pretrained_dict = torch.load(os.path.join(pwd,'net_params.pkl'))

#dict
net_state_dict = net.state_dict()

#delect
pretrained_dict_1 = {k:v for k, v in pretrained_dict.items() if k in net_state_dict}

#update
net_state_dict.update(pretrained_dict_1)

#将包含预训练模型参数的字典放到新模型中
net.load_state_dict(net_state_dict)
# Out:
# <All keys matched successfully>

# %%
#--------- step 3/5: 定义损失函数和优化器

# 按需设置学习率

#将fc3层的参数从原始网络参数中剔除
ignored_params = list(map(id, net.fc3.parameters()))
base_params = filter(lambda p: id(p) not in ignored_params, net.parameters())

#为fc3层设置需要的学习率
optimizer = optim.SGD(
                      [
                       {'params': base_params},
                       {'params': net.fc3.parameters(),'lr':lr_init*10}
                       ],
                      lr_init,
                      momentum=0.9,
                      weight_decay=1e-4
                      )

criterion = nn.CrossEntropyLoss()
# 每过50个epoch 学习率就乘0.1
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

# %%
# ---------- step 4/5 :训练
for epoch in range(max_epoch):
  loss_sigma = 0.0 # 记录一个epoch的loss之和
  correct = 0.0
  total = 0.0
  

  for i, data in enumerate(train_loader):
    #获取图片和标签
    inputs, labels = data
    inputs, labels = Variable(inputs), Variable(labels)

    
    outputs = net(inputs)
    loss = criterion(outputs, labels)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    #统计预测信息
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).squeeze().sum().numpy()
    loss_sigma += loss.item()

    #每10个iter打印一次训练信息  loss为10个iter的平均
    if i % 10 == 9 :
      loss_avg = loss_sigma / 10
      loss_sigma = 0.0
      print('Training : Epoch[{:0>3}/{:0>3}] Iteration[{:0>3}/{:0>3}] Loss {:.4f} Acc:{:.2%}'
      .format(epoch + 1, max_epoch, i + 1, len(train_loader), loss_avg, correct / total))
  print('参数组1的学习率:{},参数组2的学习率:{}'.format(scheduler.get_lr()[0],scheduler.get_lr()[1]))
    
  loss_sigma = 0.0
  cls_num = len(classes_name)
  conf_mat = np.zeros([cls_num, cls_num])  # 混淆矩阵
  net.eval()
  for i, data in enumerate(valid_loader):
    # 获取图片和标签
    images, labels = data
    images, labels = Variable(images), Variable(labels)

    # forward
    outputs = net(images)
    outputs.detach_()

    # 计算loss
    loss = criterion(outputs, labels)
    loss_sigma += loss.item()

    # 统计
    _, predicted = torch.max(outputs.data, 1)
    # labels = labels.data    # Variable --> tensor

    # 统计混淆矩阵
    for j in range(len(labels)):
      cate_i = labels[j].numpy()
      pre_i = predicted[j].numpy()
      conf_mat[cate_i, pre_i] += 1.0

    print('{} set Accuracy:{:.2%}'.format('Valid', conf_mat.trace() / conf_mat.sum()))

  scheduler.step() #更新学习率
print('Finished Training')
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Training : Epoch[076/200] Iteration[020/125] Loss 0.8202 Acc:70.62%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[076/200] Iteration[030/125] Loss 0.8011 Acc:70.05%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[076/200] Iteration[040/125] Loss 0.7860 Acc:70.08%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[076/200] Iteration[050/125] Loss 0.7955 Acc:70.56%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[076/200] Iteration[060/125] Loss 0.9155 Acc:70.23%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[076/200] Iteration[070/125] Loss 0.8689 Acc:70.00%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[076/200] Iteration[080/125] Loss 0.8198 Acc:70.27%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[076/200] Iteration[090/125] Loss 0.8417 Acc:70.19%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[076/200] Iteration[100/125] Loss 0.8532 Acc:70.03%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[076/200] Iteration[110/125] Loss 0.8078 Acc:70.23%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[076/200] Iteration[120/125] Loss 0.8440 Acc:70.16%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:35.94%
# Valid set Accuracy:39.06%
# Valid set Accuracy:49.48%
# Valid set Accuracy:55.86%
# Valid set Accuracy:59.69%
# Valid set Accuracy:61.72%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.84%
# Valid set Accuracy:64.76%
# Valid set Accuracy:64.84%
# Valid set Accuracy:63.78%
# Valid set Accuracy:64.19%
# Valid set Accuracy:64.30%
# Valid set Accuracy:63.73%
# Valid set Accuracy:62.08%
# Valid set Accuracy:62.00%
# Training : Epoch[077/200] Iteration[010/125] Loss 0.8478 Acc:70.62%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[077/200] Iteration[020/125] Loss 0.8509 Acc:69.92%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[077/200] Iteration[030/125] Loss 0.8288 Acc:69.84%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[077/200] Iteration[040/125] Loss 0.8130 Acc:69.65%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[077/200] Iteration[050/125] Loss 0.8565 Acc:69.59%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[077/200] Iteration[060/125] Loss 0.8370 Acc:69.45%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[077/200] Iteration[070/125] Loss 0.8337 Acc:69.51%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[077/200] Iteration[080/125] Loss 0.7903 Acc:70.06%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[077/200] Iteration[090/125] Loss 0.8273 Acc:70.21%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[077/200] Iteration[100/125] Loss 0.8845 Acc:69.81%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[077/200] Iteration[110/125] Loss 0.8107 Acc:70.00%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[077/200] Iteration[120/125] Loss 0.8819 Acc:69.83%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:34.38%
# Valid set Accuracy:37.50%
# Valid set Accuracy:46.88%
# Valid set Accuracy:54.30%
# Valid set Accuracy:58.13%
# Valid set Accuracy:60.16%
# Valid set Accuracy:62.72%
# Valid set Accuracy:63.48%
# Valid set Accuracy:63.72%
# Valid set Accuracy:63.75%
# Valid set Accuracy:63.07%
# Valid set Accuracy:63.41%
# Valid set Accuracy:63.82%
# Valid set Accuracy:63.95%
# Valid set Accuracy:62.92%
# Valid set Accuracy:62.80%
# Training : Epoch[078/200] Iteration[010/125] Loss 0.8013 Acc:71.09%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[078/200] Iteration[020/125] Loss 0.8428 Acc:71.09%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[078/200] Iteration[030/125] Loss 0.7945 Acc:71.25%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[078/200] Iteration[040/125] Loss 0.7870 Acc:71.33%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[078/200] Iteration[050/125] Loss 0.8299 Acc:71.19%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[078/200] Iteration[060/125] Loss 0.8457 Acc:71.12%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[078/200] Iteration[070/125] Loss 0.8220 Acc:70.69%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[078/200] Iteration[080/125] Loss 0.8030 Acc:70.84%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[078/200] Iteration[090/125] Loss 0.8207 Acc:70.89%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[078/200] Iteration[100/125] Loss 0.8379 Acc:70.69%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[078/200] Iteration[110/125] Loss 0.8386 Acc:70.70%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[078/200] Iteration[120/125] Loss 0.8160 Acc:70.78%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:42.19%
# Valid set Accuracy:42.19%
# Valid set Accuracy:51.04%
# Valid set Accuracy:56.64%
# Valid set Accuracy:60.62%
# Valid set Accuracy:62.24%
# Valid set Accuracy:64.51%
# Valid set Accuracy:65.04%
# Valid set Accuracy:64.93%
# Valid set Accuracy:64.69%
# Valid set Accuracy:63.21%
# Valid set Accuracy:63.80%
# Valid set Accuracy:64.18%
# Valid set Accuracy:63.95%
# Valid set Accuracy:62.60%
# Valid set Accuracy:62.60%
# Training : Epoch[079/200] Iteration[010/125] Loss 0.8456 Acc:68.44%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[079/200] Iteration[020/125] Loss 0.8430 Acc:69.22%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[079/200] Iteration[030/125] Loss 0.8568 Acc:69.43%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[079/200] Iteration[040/125] Loss 0.8384 Acc:69.57%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[079/200] Iteration[050/125] Loss 0.8328 Acc:69.75%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[079/200] Iteration[060/125] Loss 0.8471 Acc:70.00%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[079/200] Iteration[070/125] Loss 0.8112 Acc:70.18%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[079/200] Iteration[080/125] Loss 0.7986 Acc:70.61%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[079/200] Iteration[090/125] Loss 0.8350 Acc:70.35%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[079/200] Iteration[100/125] Loss 0.8942 Acc:70.23%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[079/200] Iteration[110/125] Loss 0.7943 Acc:70.37%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[079/200] Iteration[120/125] Loss 0.8170 Acc:70.40%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy

# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[089/200] Iteration[110/125] Loss 0.8081 Acc:70.89%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[089/200] Iteration[120/125] Loss 0.7999 Acc:70.92%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:39.06%
# Valid set Accuracy:40.62%
# Valid set Accuracy:50.00%
# Valid set Accuracy:55.86%
# Valid set Accuracy:59.06%
# Valid set Accuracy:60.42%
# Valid set Accuracy:62.72%
# Valid set Accuracy:63.67%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.38%
# Valid set Accuracy:63.21%
# Valid set Accuracy:63.80%
# Valid set Accuracy:64.18%
# Valid set Accuracy:63.50%
# Valid set Accuracy:62.29%
# Valid set Accuracy:62.20%
# Training : Epoch[090/200] Iteration[010/125] Loss 0.7816 Acc:72.50%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[090/200] Iteration[020/125] Loss 0.8481 Acc:70.47%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[090/200] Iteration[030/125] Loss 0.7955 Acc:71.04%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[090/200] Iteration[040/125] Loss 0.8404 Acc:70.51%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[090/200] Iteration[050/125] Loss 0.8957 Acc:70.28%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[090/200] Iteration[060/125] Loss 0.8568 Acc:69.97%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[090/200] Iteration[070/125] Loss 0.8548 Acc:69.73%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[090/200] Iteration[080/125] Loss 0.7750 Acc:69.98%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[090/200] Iteration[090/125] Loss 0.8399 Acc:70.07%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[090/200] Iteration[100/125] Loss 0.7776 Acc:70.45%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[090/200] Iteration[110/125] Loss 0.7856 Acc:70.55%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[090/200] Iteration[120/125] Loss 0.8245 Acc:70.53%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:42.19%
# Valid set Accuracy:42.19%
# Valid set Accuracy:52.08%
# Valid set Accuracy:57.81%
# Valid set Accuracy:60.62%
# Valid set Accuracy:62.24%
# Valid set Accuracy:64.29%
# Valid set Accuracy:64.84%
# Valid set Accuracy:65.10%
# Valid set Accuracy:64.69%
# Valid set Accuracy:63.35%
# Valid set Accuracy:63.54%
# Valid set Accuracy:63.94%
# Valid set Accuracy:63.73%
# Valid set Accuracy:62.29%
# Valid set Accuracy:62.20%
# Training : Epoch[091/200] Iteration[010/125] Loss 0.8616 Acc:69.22%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[091/200] Iteration[020/125] Loss 0.8565 Acc:68.91%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[091/200] Iteration[030/125] Loss 0.8270 Acc:69.48%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[091/200] Iteration[040/125] Loss 0.8192 Acc:70.16%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[091/200] Iteration[050/125] Loss 0.8131 Acc:70.03%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[091/200] Iteration[060/125] Loss 0.8184 Acc:70.00%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[091/200] Iteration[070/125] Loss 0.8469 Acc:70.04%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[091/200] Iteration[080/125] Loss 0.7865 Acc:70.25%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[091/200] Iteration[090/125] Loss 0.8070 Acc:70.52%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[091/200] Iteration[100/125] Loss 0.8298 Acc:70.58%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[091/200] Iteration[110/125] Loss 0.8879 Acc:70.37%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[091/200] Iteration[120/125] Loss 0.8020 Acc:70.47%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:37.50%
# Valid set Accuracy:39.84%
# Valid set Accuracy:47.92%
# Valid set Accuracy:54.30%
# Valid set Accuracy:57.50%
# Valid set Accuracy:59.11%
# Valid set Accuracy:61.83%
# Valid set Accuracy:62.89%
# Valid set Accuracy:63.19%
# Valid set Accuracy:63.75%
# Valid set Accuracy:62.64%
# Valid set Accuracy:63.15%
# Valid set Accuracy:63.70%
# Valid set Accuracy:63.50%
# Valid set Accuracy:62.19%
# Valid set Accuracy:62.10%
# Training : Epoch[092/200] Iteration[010/125] Loss 0.7401 Acc:75.00%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[092/200] Iteration[020/125] Loss 0.8081 Acc:72.19%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[092/200] Iteration[030/125] Loss 0.8311 Acc:71.82%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[092/200] Iteration[040/125] Loss 0.8031 Acc:71.33%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[092/200] Iteration[050/125] Loss 0.8818 Acc:70.41%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[092/200] Iteration[060/125] Loss 0.8206 Acc:70.18%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[092/200] Iteration[070/125] Loss 0.9141 Acc:69.67%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[092/200] Iteration[080/125] Loss 0.8301 Acc:69.71%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[092/200] Iteration[090/125] Loss 0.8108 Acc:69.95%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[092/200] Iteration[100/125] Loss 0.7892 Acc:70.17%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[092/200] Iteration[110/125] Loss 0.8088 Acc:70.33%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[092/200] Iteration[120/125] Loss 0.7990 Acc:70.40%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:40.62%
# Valid set Accuracy:42.19%
# Valid set Accuracy:51.56%
# Valid set Accuracy:57.42%
# Valid set Accuracy:59.69%
# Valid set Accuracy:61.20%
# Valid set Accuracy:63.62%
# Valid set Accuracy:64.26%
# Valid set Accuracy:64.24%
# Valid set Accuracy:64.69%
# Valid set Accuracy:63.49%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.18%
# Valid set Accuracy:63.39%
# Valid set Accuracy:62.08%
# Valid set Accuracy:62.00%
# Training : Epoch[093/200] Iteration[010/125] Loss 0.8179 Acc:69.69%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[093/200] Iteration[020/125] Loss 0.8319 Acc:70.31%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[093/200] Iteration[030/125] Loss 0.8470 Acc:70.36%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[093/200] Iteration[040/125] Loss 0.7711 Acc:71.41%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[093/200] Iteration[050/125] Loss 0.7217 Acc:71.78%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[093/200] Iteration[060/125] Loss 0.8629 Acc:71.48%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[093/200] Iteration[070/125] Loss 0.8392 Acc:71.03%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[093/200] Iteration[080/125] Loss 0.7935 Acc:71.09%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[093/200] Iteration[090/125] Loss 0.8422 Acc:70.92%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[093/200] Iteration[100/125] Loss 0.7673 Acc:71.09%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[093/200] Iteration[110/125] Loss 0.8559 Acc:70.84%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[093/200] Iteration[120/125] Loss 0.7804 Acc:70.87%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:39.06%
# Valid set Accuracy:39.84%
# Valid set Accuracy:48.44%
# Valid set Accuracy:54.30%
# Valid set Accuracy:58.13%
# Valid set Accuracy:59.90%
# Valid set Accuracy:62.50%
# Valid set Accuracy:63.48%
# Valid set Accuracy:63.72%
# Valid set Accuracy:63.91%
# Valid set Accuracy:62.78%
# Valid set Accuracy:63.15%
# Valid set Accuracy:63.58%
# Valid set Accuracy:63.39%
# Valid set Accuracy:62.08%
# Valid set Accuracy:62.00%
# Training : Epoch[094/200] Iteration[010/125] Loss 0.8142 Acc:71.72%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[094/200] Iteration[020/125] Loss 0.8271 Acc:71.25%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[094/200] Iteration[030/125] Loss 0.8023 Acc:71.41%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[094/200] Iteration[040/125] Loss 0.7958 Acc:71.60%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[094/200] Iteration[050/125] Loss 0.8281 Acc:71.12%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[094/200] Iteration[060/125] Loss 0.8717 Acc:70.86%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[094/200] Iteration[070/125] Loss 0.8824 Acc:70.49%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[094/200] Iteration[080/125] Loss 0.8762 Acc:69.98%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[094/200] Iteration[090/125] Loss 0.7905 Acc:69.97%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[094/200] Iteration[100/125] Loss 0.8590 Acc:70.03%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[094/200] Iteration[110/125] Loss 0.8226 Acc:70.10%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[094/200] Iteration[120/125] Loss 0.7782 Acc:70.38%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:35.94%
# Valid set Accuracy:38.28%
# Valid set Accuracy:47.92%
# Valid set Accuracy:54.69%
# Valid set Accuracy:59.06%
# Valid set Accuracy:60.94%
# Valid set Accuracy:63.39%
# Valid set Accuracy:64.26%
# Valid set Accuracy:64.41%
# Valid set Accuracy:64.84%
# Valid set Accuracy:63.49%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.06%
# Valid set Accuracy:63.28%
# Valid set Accuracy:62.29%
# Valid set Accuracy:62.20%
# Training : Epoch[095/200] Iteration[010/125] Loss 0.7806 Acc:71.56%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[095/200] Iteration[020/125] Loss 0.8046 Acc:71.41%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[095/200] Iteration[030/125] Loss 0.8577 Acc:70.73%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[095/200] Iteration[040/125] Loss 0.7867 Acc:70.98%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[095/200] Iteration[050/125] Loss 0.7950 Acc:70.88%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[095/200] Iteration[060/125] Loss 0.8715 Acc:70.39%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[095/200] Iteration[070/125] Loss 0.8109 Acc:70.56%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[095/200] Iteration[080/125] Loss 0.8129 Acc:70.59%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[095/200] Iteration[090/125] Loss 0.8436 Acc:70.64%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[095/200] Iteration[100/125] Loss 0.8205 Acc:70.80%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[095/200] Iteration[110/125] Loss 0.7240 Acc:70.91%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[095/200] Iteration[120/125] Loss 0.7876 Acc:70.89%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:43.75%
# Valid set Accuracy:43.75%
# Valid set Accuracy:52.08%
# Valid set Accuracy:57.81%
# Valid set Accuracy:60.62%
# Valid set Accuracy:61.98%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.45%
# Valid set Accuracy:64.93%
# Valid set Accuracy:64.38%
# Valid set Accuracy:62.64%
# Valid set Accuracy:63.02%
# Valid set Accuracy:63.58%
# Valid set Accuracy:63.28%
# Valid set Accuracy:62.19%
# Valid set Accuracy:62.10%
# Training : Epoch[096/200] Iteration[010/125] Loss 0.8293 Acc:69.69%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[096/200] Iteration[020/125] Loss 0.8218 Acc:70.16%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[096/200] Iteration[030/125] Loss 0.7991 Acc:70.26%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[096/200] Iteration[040/125] Loss 0.8089 Acc:70.66%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[096/200] Iteration[050/125] Loss 0.8465 Acc:70.84%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[096/200] Iteration[060/125] Loss 0.8318 Acc:70.96%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[096/200] Iteration[070/125] Loss 0.8010 Acc:71.07%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[096/200] Iteration[080/125] Loss 0.8906 Acc:70.55%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[096/200] Iteration[090/125] Loss 0.8609 Acc:70.30%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[096/200] Iteration[100/125] Loss 0.8791 Acc:70.19%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[096/200] Iteration[110/125] Loss 0.8358 Acc:70.18%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[096/200] Iteration[120/125] Loss 0.7425 Acc:70.48%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:40.62%
# Valid set Accuracy:40.62%
# Valid set Accuracy:49.48%
# Valid set Accuracy:55.47%
# Valid set Accuracy:58.75%
# Valid set Accuracy:60.68%
# Valid set Accuracy:63.17%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.24%
# Valid set Accuracy:64.69%
# Valid set Accuracy:63.49%
# Valid set Accuracy:63.93%
# Valid set Accuracy:64.06%
# Valid set Accuracy:63.39%
# Valid set Accuracy:62.29%
# Valid set Accuracy:62.20%
# Training : Epoch[097/200] Iteration[010/125] Loss 0.7707 Acc:72.66%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[097/200] Iteration[020/125] Loss 0.7808 Acc:71.80%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[097/200] Iteration[030/125] Loss 0.8360 Acc:71.15%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[097/200] Iteration[040/125] Loss 0.7560 Acc:72.23%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[097/200] Iteration[050/125] Loss 0.7926 Acc:72.19%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[097/200] Iteration[060/125] Loss 0.8544 Acc:71.69%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[097/200] Iteration[070/125] Loss 0.8527 Acc:71.36%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[097/200] Iteration[080/125] Loss 0.8597 Acc:71.17%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[097/200] Iteration[090/125] Loss 0.7499 Acc:71.49%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[097/200] Iteration[100/125] Loss 0.8317 Acc:71.28%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[097/200] Iteration[110/125] Loss 0.8525 Acc:71.11%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[097/200] Iteration[120/125] Loss 0.8653 Acc:70.99%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:35.94%
# Valid set Accuracy:39.84%
# Valid set Accuracy:48.44%
# Valid set Accuracy:55.08%
# Valid set Accuracy:58.44%
# Valid set Accuracy:60.16%
# Valid set Accuracy:62.72%
# Valid set Accuracy:63.67%
# Valid set Accuracy:63.89%
# Valid set Accuracy:64.22%
# Valid set Accuracy:63.21%
# Valid set Accuracy:63.54%
# Valid set Accuracy:63.70%
# Valid set Accuracy:63.28%
# Valid set Accuracy:62.29%
# Valid set Accuracy:62.20%
# Training : Epoch[098/200] Iteration[010/125] Loss 0.8402 Acc:69.53%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[098/200] Iteration[020/125] Loss 0.8353 Acc:71.09%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[098/200] Iteration[030/125] Loss 0.8096 Acc:71.04%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[098/200] Iteration[040/125] Loss 0.8479 Acc:70.62%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[098/200] Iteration[050/125] Loss 0.8144 Acc:70.66%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[098/200] Iteration[060/125] Loss 0.7994 Acc:70.78%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[098/200] Iteration[070/125] Loss 0.7859 Acc:70.71%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[098/200] Iteration[080/125] Loss 0.8660 Acc:70.33%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[098/200] Iteration[090/125] Loss 0.8091 Acc:70.36%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[098/200] Iteration[100/125] Loss 0.7525 Acc:70.73%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[098/200] Iteration[110/125] Loss 0.8454 Acc:70.72%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[098/200] Iteration[120/125] Loss 0.8217 Acc:70.60%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Valid set Accuracy:40.62%
# Valid set Accuracy:40.62%
# Valid set Accuracy:49.48%
# Valid set Accuracy:55.86%
# Valid set Accuracy:58.75%
# Valid set Accuracy:60.42%
# Valid set Accuracy:62.95%
# Valid set Accuracy:63.67%
# Valid set Accuracy:63.89%
# Valid set Accuracy:63.91%
# Valid set Accuracy:62.50%
# Valid set Accuracy:63.02%
# Valid set Accuracy:63.58%
# Valid set Accuracy:63.17%
# Valid set Accuracy:61.98%
# Valid set Accuracy:61.90%
# Training : Epoch[099/200] Iteration[010/125] Loss 0.7785 Acc:71.88%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[099/200] Iteration[020/125] Loss 0.8532 Acc:71.25%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[099/200] Iteration[030/125] Loss 0.8141 Acc:71.35%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch[099/200] Iteration[040/125] Loss 0.8609 Acc:70.90%
# 参数组1的学习率:0.0001,参数组2的学习率:0.001
# Training : Epoch

# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[101/200] Iteration[120/125] Loss 0.7792 Acc:70.95%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Valid set Accuracy:37.50%
# Valid set Accuracy:39.84%
# Valid set Accuracy:48.96%
# Valid set Accuracy:55.47%
# Valid set Accuracy:58.13%
# Valid set Accuracy:59.90%
# Valid set Accuracy:62.50%
# Valid set Accuracy:63.28%
# Valid set Accuracy:63.54%
# Valid set Accuracy:63.59%
# Valid set Accuracy:62.78%
# Valid set Accuracy:63.15%
# Valid set Accuracy:63.82%
# Valid set Accuracy:63.50%
# Valid set Accuracy:61.98%
# Valid set Accuracy:61.90%
# Training : Epoch[102/200] Iteration[010/125] Loss 0.7407 Acc:72.34%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[102/200] Iteration[020/125] Loss 0.8149 Acc:71.72%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[102/200] Iteration[030/125] Loss 0.7919 Acc:72.14%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[102/200] Iteration[040/125] Loss 0.8299 Acc:71.91%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[102/200] Iteration[050/125] Loss 0.8369 Acc:71.66%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[102/200] Iteration[060/125] Loss 0.8179 Acc:71.41%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[102/200] Iteration[070/125] Loss 0.7358 Acc:71.76%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[102/200] Iteration[080/125] Loss 0.8606 Acc:71.45%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[102/200] Iteration[090/125] Loss 0.7015 Acc:71.77%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[102/200] Iteration[100/125] Loss 0.8514 Acc:71.47%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[102/200] Iteration[110/125] Loss 0.9023 Acc:71.01%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[102/200] Iteration[120/125] Loss 0.7764 Acc:71.29%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Valid set Accuracy:37.50%
# Valid set Accuracy:39.84%
# Valid set Accuracy:48.96%
# Valid set Accuracy:55.47%
# Valid set Accuracy:58.13%
# Valid set Accuracy:59.90%
# Valid set Accuracy:62.50%
# Valid set Accuracy:63.28%
# Valid set Accuracy:63.54%
# Valid set Accuracy:63.75%
# Valid set Accuracy:62.93%
# Valid set Accuracy:63.28%
# Valid set Accuracy:63.70%
# Valid set Accuracy:63.28%
# Valid set Accuracy:61.88%
# Valid set Accuracy:61.80%
# Training : Epoch[103/200] Iteration[010/125] Loss 0.8286 Acc:70.31%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[103/200] Iteration[020/125] Loss 0.7756 Acc:72.66%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[103/200] Iteration[030/125] Loss 0.7956 Acc:72.08%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[103/200] Iteration[040/125] Loss 0.8315 Acc:71.56%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[103/200] Iteration[050/125] Loss 0.7837 Acc:71.88%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[103/200] Iteration[060/125] Loss 0.8462 Acc:71.59%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[103/200] Iteration[070/125] Loss 0.8247 Acc:71.50%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[103/200] Iteration[080/125] Loss 0.8390 Acc:71.27%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[103/200] Iteration[090/125] Loss 0.8486 Acc:70.95%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[103/200] Iteration[100/125] Loss 0.7564 Acc:70.98%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[103/200] Iteration[110/125] Loss 0.8662 Acc:70.91%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[103/200] Iteration[120/125] Loss 0.8187 Acc:70.99%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Valid set Accuracy:39.06%
# Valid set Accuracy:40.62%
# Valid set Accuracy:51.04%
# Valid set Accuracy:57.03%
# Valid set Accuracy:59.69%
# Valid set Accuracy:61.46%
# Valid set Accuracy:63.84%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.24%
# Valid set Accuracy:64.22%
# Valid set Accuracy:63.35%
# Valid set Accuracy:63.67%
# Valid set Accuracy:64.06%
# Valid set Accuracy:63.62%
# Valid set Accuracy:62.19%
# Valid set Accuracy:62.10%
# Training : Epoch[104/200] Iteration[010/125] Loss 0.8214 Acc:69.22%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[104/200] Iteration[020/125] Loss 0.8405 Acc:69.38%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[104/200] Iteration[030/125] Loss 0.8338 Acc:69.32%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[104/200] Iteration[040/125] Loss 0.8401 Acc:69.49%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[104/200] Iteration[050/125] Loss 0.8279 Acc:69.69%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[104/200] Iteration[060/125] Loss 0.7677 Acc:70.31%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[104/200] Iteration[070/125] Loss 0.7508 Acc:70.78%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[104/200] Iteration[080/125] Loss 0.7500 Acc:70.96%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[104/200] Iteration[090/125] Loss 0.7958 Acc:70.85%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[104/200] Iteration[100/125] Loss 0.7908 Acc:70.88%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[104/200] Iteration[110/125] Loss 0.8049 Acc:70.85%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[104/200] Iteration[120/125] Loss 0.8002 Acc:70.95%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Valid set Accuracy:39.06%
# Valid set Accuracy:40.62%
# Valid set Accuracy:50.00%
# Valid set Accuracy:56.25%
# Valid set Accuracy:58.75%
# Valid set Accuracy:60.42%
# Valid set Accuracy:62.95%
# Valid set Accuracy:63.28%
# Valid set Accuracy:63.54%
# Valid set Accuracy:63.44%
# Valid set Accuracy:62.64%
# Valid set Accuracy:63.15%
# Valid set Accuracy:63.46%
# Valid set Accuracy:63.06%
# Valid set Accuracy:61.77%
# Valid set Accuracy:61.70%
# Training : Epoch[105/200] Iteration[010/125] Loss 0.8369 Acc:70.78%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[105/200] Iteration[020/125] Loss 0.8660 Acc:70.39%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[105/200] Iteration[030/125] Loss 0.8239 Acc:70.26%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[105/200] Iteration[040/125] Loss 0.7971 Acc:70.39%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[105/200] Iteration[050/125] Loss 0.8083 Acc:70.56%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[105/200] Iteration[060/125] Loss 0.7387 Acc:71.02%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[105/200] Iteration[070/125] Loss 0.7612 Acc:71.25%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[105/200] Iteration[080/125] Loss 0.8199 Acc:71.19%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[105/200] Iteration[090/125] Loss 0.8447 Acc:70.82%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[105/200] Iteration[100/125] Loss 0.7419 Acc:70.95%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[105/200] Iteration[110/125] Loss 0.7789 Acc:70.95%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Training : Epoch[105/200] Iteration[120/125] Loss 0.8056 Acc:70.89%
# 参数组1的学习率:1e-05,参数组2的学习率:0.0001
# Valid set Accuracy:39.06%
# Valid set Accuracy:40.62%
# Valid set Accuracy:51.04%
# Valid set Accuracy:57.03%
# Valid set Accuracy:59.69%
# Valid set Accuracy:61.20%
# ...
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[192/200] Iteration[030/125] Loss 0.7717 Acc:70.10%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[192/200] Iteration[040/125] Loss 0.8447 Acc:70.55%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[192/200] Iteration[050/125] Loss 0.7578 Acc:71.41%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[192/200] Iteration[060/125] Loss 0.8044 Acc:71.46%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[192/200] Iteration[070/125] Loss 0.7726 Acc:71.65%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[192/200] Iteration[080/125] Loss 0.7918 Acc:71.52%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[192/200] Iteration[090/125] Loss 0.8159 Acc:71.60%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[192/200] Iteration[100/125] Loss 0.7667 Acc:71.64%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[192/200] Iteration[110/125] Loss 0.7974 Acc:71.58%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[192/200] Iteration[120/125] Loss 0.8118 Acc:71.37%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Valid set Accuracy:40.62%
# Valid set Accuracy:42.19%
# Valid set Accuracy:51.56%
# Valid set Accuracy:57.03%
# Valid set Accuracy:59.69%
# Valid set Accuracy:61.20%
# Valid set Accuracy:63.62%
# Valid set Accuracy:64.26%
# Valid set Accuracy:64.41%
# Valid set Accuracy:64.84%
# Valid set Accuracy:63.78%
# Valid set Accuracy:64.19%
# Valid set Accuracy:64.54%
# Valid set Accuracy:64.06%
# Valid set Accuracy:62.71%
# Valid set Accuracy:62.60%
# Training : Epoch[193/200] Iteration[010/125] Loss 0.7881 Acc:71.88%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[193/200] Iteration[020/125] Loss 0.7806 Acc:72.42%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[193/200] Iteration[030/125] Loss 0.7618 Acc:71.77%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[193/200] Iteration[040/125] Loss 0.8489 Acc:71.33%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[193/200] Iteration[050/125] Loss 0.7448 Acc:71.25%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[193/200] Iteration[060/125] Loss 0.8064 Acc:71.30%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[193/200] Iteration[070/125] Loss 0.8085 Acc:71.32%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[193/200] Iteration[080/125] Loss 0.8016 Acc:71.29%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[193/200] Iteration[090/125] Loss 0.7917 Acc:71.13%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[193/200] Iteration[100/125] Loss 0.8008 Acc:71.27%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[193/200] Iteration[110/125] Loss 0.7234 Acc:71.52%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[193/200] Iteration[120/125] Loss 0.8622 Acc:71.30%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Valid set Accuracy:40.62%
# Valid set Accuracy:42.19%
# Valid set Accuracy:51.56%
# Valid set Accuracy:57.03%
# Valid set Accuracy:59.38%
# Valid set Accuracy:60.94%
# Valid set Accuracy:63.39%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.24%
# Valid set Accuracy:64.69%
# Valid set Accuracy:63.64%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.42%
# Valid set Accuracy:63.95%
# Valid set Accuracy:62.60%
# Valid set Accuracy:62.50%
# Training : Epoch[194/200] Iteration[010/125] Loss 0.7933 Acc:72.34%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[194/200] Iteration[020/125] Loss 0.7904 Acc:72.03%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[194/200] Iteration[030/125] Loss 0.8017 Acc:70.94%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[194/200] Iteration[040/125] Loss 0.8027 Acc:71.33%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[194/200] Iteration[050/125] Loss 0.8357 Acc:71.19%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[194/200] Iteration[060/125] Loss 0.7975 Acc:71.33%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[194/200] Iteration[070/125] Loss 0.8174 Acc:71.00%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[194/200] Iteration[080/125] Loss 0.7452 Acc:71.37%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[194/200] Iteration[090/125] Loss 0.7449 Acc:71.68%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[194/200] Iteration[100/125] Loss 0.7998 Acc:71.48%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[194/200] Iteration[110/125] Loss 0.8341 Acc:71.31%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[194/200] Iteration[120/125] Loss 0.7600 Acc:71.46%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Valid set Accuracy:40.62%
# Valid set Accuracy:42.19%
# Valid set Accuracy:51.56%
# Valid set Accuracy:57.03%
# Valid set Accuracy:59.38%
# Valid set Accuracy:60.94%
# Valid set Accuracy:63.39%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.24%
# Valid set Accuracy:64.69%
# Valid set Accuracy:63.64%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.42%
# Valid set Accuracy:63.95%
# Valid set Accuracy:62.60%
# Valid set Accuracy:62.50%
# Training : Epoch[195/200] Iteration[010/125] Loss 0.7532 Acc:75.16%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[195/200] Iteration[020/125] Loss 0.7512 Acc:73.44%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[195/200] Iteration[030/125] Loss 0.8313 Acc:72.50%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[195/200] Iteration[040/125] Loss 0.7953 Acc:71.68%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[195/200] Iteration[050/125] Loss 0.8098 Acc:71.44%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[195/200] Iteration[060/125] Loss 0.7969 Acc:71.15%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[195/200] Iteration[070/125] Loss 0.8446 Acc:70.89%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[195/200] Iteration[080/125] Loss 0.7530 Acc:71.27%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[195/200] Iteration[090/125] Loss 0.7832 Acc:71.25%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[195/200] Iteration[100/125] Loss 0.8196 Acc:71.30%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[195/200] Iteration[110/125] Loss 0.8238 Acc:70.99%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[195/200] Iteration[120/125] Loss 0.8099 Acc:70.95%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Valid set Accuracy:40.62%
# Valid set Accuracy:42.19%
# Valid set Accuracy:51.56%
# Valid set Accuracy:57.03%
# Valid set Accuracy:59.38%
# Valid set Accuracy:60.94%
# Valid set Accuracy:63.39%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.24%
# Valid set Accuracy:64.69%
# Valid set Accuracy:63.64%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.42%
# Valid set Accuracy:63.95%
# Valid set Accuracy:62.71%
# Valid set Accuracy:62.60%
# Training : Epoch[196/200] Iteration[010/125] Loss 0.7551 Acc:73.28%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[196/200] Iteration[020/125] Loss 0.8361 Acc:71.48%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[196/200] Iteration[030/125] Loss 0.8192 Acc:70.73%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[196/200] Iteration[040/125] Loss 0.8267 Acc:70.78%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[196/200] Iteration[050/125] Loss 0.8327 Acc:71.28%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[196/200] Iteration[060/125] Loss 0.8428 Acc:71.28%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[196/200] Iteration[070/125] Loss 0.7416 Acc:71.67%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[196/200] Iteration[080/125] Loss 0.8085 Acc:71.60%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[196/200] Iteration[090/125] Loss 0.7830 Acc:71.56%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[196/200] Iteration[100/125] Loss 0.7635 Acc:71.75%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[196/200] Iteration[110/125] Loss 0.8456 Acc:71.70%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[196/200] Iteration[120/125] Loss 0.7678 Acc:71.59%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Valid set Accuracy:40.62%
# Valid set Accuracy:42.19%
# Valid set Accuracy:51.56%
# Valid set Accuracy:57.03%
# Valid set Accuracy:59.38%
# Valid set Accuracy:60.94%
# Valid set Accuracy:63.39%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.24%
# Valid set Accuracy:64.69%
# Valid set Accuracy:63.64%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.42%
# Valid set Accuracy:63.95%
# Valid set Accuracy:62.71%
# Valid set Accuracy:62.60%
# Training : Epoch[197/200] Iteration[010/125] Loss 0.8657 Acc:67.81%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[197/200] Iteration[020/125] Loss 0.7983 Acc:69.61%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[197/200] Iteration[030/125] Loss 0.8080 Acc:69.53%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[197/200] Iteration[040/125] Loss 0.8424 Acc:69.77%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[197/200] Iteration[050/125] Loss 0.7501 Acc:70.56%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[197/200] Iteration[060/125] Loss 0.7761 Acc:70.81%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[197/200] Iteration[070/125] Loss 0.7844 Acc:70.85%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[197/200] Iteration[080/125] Loss 0.8505 Acc:70.76%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[197/200] Iteration[090/125] Loss 0.7515 Acc:71.06%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[197/200] Iteration[100/125] Loss 0.7241 Acc:71.31%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[197/200] Iteration[110/125] Loss 0.8311 Acc:71.18%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[197/200] Iteration[120/125] Loss 0.8207 Acc:71.20%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Valid set Accuracy:40.62%
# Valid set Accuracy:42.19%
# Valid set Accuracy:51.56%
# Valid set Accuracy:57.03%
# Valid set Accuracy:59.38%
# Valid set Accuracy:60.94%
# Valid set Accuracy:63.39%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.24%
# Valid set Accuracy:64.69%
# Valid set Accuracy:63.64%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.42%
# Valid set Accuracy:63.95%
# Valid set Accuracy:62.60%
# Valid set Accuracy:62.50%
# Training : Epoch[198/200] Iteration[010/125] Loss 0.8325 Acc:68.28%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[198/200] Iteration[020/125] Loss 0.8026 Acc:69.77%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[198/200] Iteration[030/125] Loss 0.7967 Acc:70.36%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[198/200] Iteration[040/125] Loss 0.8030 Acc:71.02%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[198/200] Iteration[050/125] Loss 0.8316 Acc:70.91%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[198/200] Iteration[060/125] Loss 0.8531 Acc:70.62%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[198/200] Iteration[070/125] Loss 0.7508 Acc:70.76%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[198/200] Iteration[080/125] Loss 0.7980 Acc:70.92%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[198/200] Iteration[090/125] Loss 0.8015 Acc:71.08%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[198/200] Iteration[100/125] Loss 0.8196 Acc:71.05%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[198/200] Iteration[110/125] Loss 0.8542 Acc:70.67%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[198/200] Iteration[120/125] Loss 0.7911 Acc:70.65%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Valid set Accuracy:40.62%
# Valid set Accuracy:42.19%
# Valid set Accuracy:51.56%
# Valid set Accuracy:57.03%
# Valid set Accuracy:59.38%
# Valid set Accuracy:60.94%
# Valid set Accuracy:63.39%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.24%
# Valid set Accuracy:64.69%
# Valid set Accuracy:63.64%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.42%
# Valid set Accuracy:63.95%
# Valid set Accuracy:62.60%
# Valid set Accuracy:62.50%
# Training : Epoch[199/200] Iteration[010/125] Loss 0.8209 Acc:72.19%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[199/200] Iteration[020/125] Loss 0.8198 Acc:70.94%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[199/200] Iteration[030/125] Loss 0.7939 Acc:70.89%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[199/200] Iteration[040/125] Loss 0.7849 Acc:71.48%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[199/200] Iteration[050/125] Loss 0.7942 Acc:71.75%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[199/200] Iteration[060/125] Loss 0.7972 Acc:71.74%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[199/200] Iteration[070/125] Loss 0.7896 Acc:71.94%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[199/200] Iteration[080/125] Loss 0.8201 Acc:71.93%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[199/200] Iteration[090/125] Loss 0.8826 Acc:71.65%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[199/200] Iteration[100/125] Loss 0.8054 Acc:71.55%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[199/200] Iteration[110/125] Loss 0.8219 Acc:71.34%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[199/200] Iteration[120/125] Loss 0.7684 Acc:71.28%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Valid set Accuracy:40.62%
# Valid set Accuracy:42.19%
# Valid set Accuracy:51.56%
# Valid set Accuracy:57.03%
# Valid set Accuracy:59.38%
# Valid set Accuracy:60.94%
# Valid set Accuracy:63.39%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.24%
# Valid set Accuracy:64.69%
# Valid set Accuracy:63.64%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.42%
# Valid set Accuracy:63.95%
# Valid set Accuracy:62.71%
# Valid set Accuracy:62.60%
# Training : Epoch[200/200] Iteration[010/125] Loss 0.7741 Acc:72.34%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[200/200] Iteration[020/125] Loss 0.8785 Acc:70.78%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[200/200] Iteration[030/125] Loss 0.8138 Acc:70.89%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[200/200] Iteration[040/125] Loss 0.7913 Acc:70.74%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[200/200] Iteration[050/125] Loss 0.8407 Acc:70.56%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[200/200] Iteration[060/125] Loss 0.8237 Acc:70.55%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[200/200] Iteration[070/125] Loss 0.8079 Acc:70.47%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[200/200] Iteration[080/125] Loss 0.8648 Acc:70.49%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[200/200] Iteration[090/125] Loss 0.8393 Acc:70.35%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[200/200] Iteration[100/125] Loss 0.7343 Acc:70.64%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[200/200] Iteration[110/125] Loss 0.8225 Acc:70.48%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Training : Epoch[200/200] Iteration[120/125] Loss 0.7178 Acc:70.76%
# 参数组1的学习率:1.0000000000000002e-06,参数组2的学习率:1e-05
# Valid set Accuracy:40.62%
# Valid set Accuracy:42.19%
# Valid set Accuracy:51.56%
# Valid set Accuracy:57.03%
# Valid set Accuracy:59.38%
# Valid set Accuracy:60.94%
# Valid set Accuracy:63.39%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.24%
# Valid set Accuracy:64.69%
# Valid set Accuracy:63.64%
# Valid set Accuracy:64.06%
# Valid set Accuracy:64.42%
# Valid set Accuracy:63.95%
# Valid set Accuracy:62.71%
# Valid set Accuracy:62.60%
# Finished Training

# %%
conf_mat_train, train_acc = validate(net, train_loader, 'train', classes_name)
conf_mat_valid, valid_acc = validate(net, valid_loader, 'valid', classes_name)

show_confMat(conf_mat_train, classes_name, 'train', log_dir)
show_confMat(conf_mat_valid, classes_name, 'valid', log_dir)
# Out:
# class;plane     , total num:800.0 , correct num:614.0  Recall:76.65%  Precision:75.25%
# class;car       , total num:800.0 , correct num:676.0  Recall:84.39%  Precision:78.33%
# class;bird      , total num:800.0 , correct num:472.0  Recall:58.93%  Precision:65.46%
# class;cat       , total num:800.0 , correct num:401.0  Recall:50.06%  Precision:56.80%
# class;deer      , total num:800.0 , correct num:548.0  Recall:68.41%  Precision:61.71%
# class;dog       , total num:800.0 , correct num:515.0  Recall:64.29%  Precision:64.54%
# class;frog      , total num:800.0 , correct num:633.0  Recall:79.03%  Precision:76.27%
# class;horse     , total num:800.0 , correct num:598.0  Recall:74.66%  Precision:75.41%
# class;ship      , total num:800.0 , correct num:653.0  Recall:81.52%  Precision:80.72%
# class;truck     , total num:800.0 , correct num:617.0  Recall:77.03%  Precision:78.50%
# train set Accuracy:71.59%
# class;plane     , total num:100.0 , correct num:73.0   Recall:72.28%  Precision:59.84%
# class;car       , total num:100.0 , correct num:71.0   Recall:70.30%  Precision:67.62%
# class;bird      , total num:100.0 , correct num:50.0   Recall:49.50%  Precision:48.08%
# class;cat       , total num:100.0 , correct num:36.0   Recall:35.64%  Precision:45.00%
# class;deer      , total num:100.0 , correct num:59.0   Recall:58.42%  Precision:62.77%
# class;dog       , total num:100.0 , correct num:56.0   Recall:55.45%  Precision:51.85%
# class;frog      , total num:100.0 , correct num:68.0   Recall:67.33%  Precision:71.58%
# class;horse     , total num:100.0 , correct num:73.0   Recall:72.28%  Precision:62.93%
# class;ship      , total num:100.0 , correct num:70.0   Recall:69.31%  Precision:79.55%
# class;truck     , total num:100.0 , correct num:70.0   Recall:69.31%  Precision:71.43%
# valid set Accuracy:62.60%

# %%
torch.cuda.get_device_name(0)
# Out:
# 'Tesla P4'
